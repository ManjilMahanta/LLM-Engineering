# %%
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import display, Markdown, update_display
load_dotenv(override=True)
MODEL="llama3.2"
client = OpenAI(base_url="http://localhost:11434/v1", api_key="not_needed")
messages = [{"role": "system", "content": "You are a helpful assistant that translates English to French."}]
for i in range(3):
    user_input = input("Enter text to translate to French: ")
    messages.append({"role": "user", "content": user_input})
    response = client.chat.completions.create(
        model=MODEL,
        messages=messages)
    assistant_message = response.choices[0].message.content
    messages.append({"role": "assistant", "content": assistant_message})
    display(Markdown(f"**French Translation {i+1}:** {assistant_message}"))
# Out:
# **French Translation 1:** Bonjour ! Comment puis-je vous aider aujourd'hui ?
# **French Translation 2:** Bonjour ! Comment allez-vous ?
# **French Translation 3:** C'est un peu court, mais je comprends. Vous voulez dire "allé" et non "aller", n'est-ce pas ? En français, "allé" est le verbe correct dans ce contexte.
#
# Vous pouvez essayer à nouveau s'il vous plaît. Je suis là pour vous aider !
